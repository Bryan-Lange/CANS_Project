# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno
from scipy import stats
import datetime
import names
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 10)
np.random.seed(1984)

# %% [markdown]
# ## Create Main CANS DataFrame

# %%
Comprehensive = ["Case Number","Child's Name","DOB","Date of Assessment","Assessor","Family Functioning","Living Situation","Social Functioning","Recreational","Developmental_Intellectual","Job Functioning","Legal","Medical_Physical","Sexual Development","Sleep","School Behavior","School Attendance","School Achievement","Decision_Making","Family Strengths","Interpersonal","Optimism","Educational Setting","Vocational","Talents_Interests","Spiritual_Religious","Community Life","Relationship Permanence","Resiliency","Resourcefulness","Cultural Identity","Natural Supports","Language",
"Traditions_Rituals","Cultural Stress","Supervision","Involvement_with_Care","Knowledge","Organization","Social Resources","Residential Stability","Medical_Physical","Mental Health","Substance_Usage",
"Developmental","Safety","Psychosis","Impulsivity_Hyperactivity","Depression","Anxiety","Oppositional","Conduct","Adjustment to Trauma","Attachment Difficulties","Anger Control","Substance_Use",
"Suicide Risk","NonSuicidal Self Injurious Behavior","Other Self Harm", "Danger to Others","Sexual Aggression","Runaway","Delinquent Behavior","Fire Setting","Intentional Misbehavior"]

# %%
data_col = ["Family_Functioning","Living_Situation","Social_Functioning","Recreational","Developmental_Intellectual","Job Functioning","Legal","Medical_Physical","Sexual Development","Sleep","School_Behavior","School_Attendance","School_Achievement","Decision_Making","Family_Strengths","Interpersonal","Optimism","Educational_Setting","Vocational","Talents_Interests","Spiritual_Religious","Community_Life","Relationship_Permanence","Resiliency","Resourcefulness","Cultural_Identity","Natural_Supports","Language",
"Traditions_Rituals","Cultural_Stress","Supervision","Involvement_with_Care","Knowledge","Organization","Social_Resources","Residential Stability","Medical_Physical","Mental_Health","Substance_Usage",
"Developmental","Safety","Psychosis","Impulsivity_Hyperactivity","Depression","Anxiety","Oppositional","Conduct","Adjustment_to_Trauma","Attachment_Difficulties","Anger_Control","Substance_Use",
"Suicide_Risk","NonSuicidal_Self_Injurious_Behavior","Other_Self_Harm", "Danger_to_Others","Sexual_Aggression","Runaway","Delinquent_Behavior","Fire_Setting","Intentional_Misbehavior"]

# %%
index = range(0,25000)

# %%
first = ["Jacob", "Ethan", "Michael", "Jayden", "William", "Alexander", "Noah", "Daniel", "Aiden", "Anthony", "Joshua", "Mason", "Christopher", "Andrew", "David", "Matthew", "Logan", "Elijah", "James", "Joseph", "Gabriel", "Benjamin", "Ryan", "Samuel", "Jackson", "John", "Nathan", "Jonathan", "Christian", "Liam", "Dylan", "Caleb", "Landon", "Tyler", "Lucas", "Evan", "Nicholas", "Gavin", "Isaac", "Brayden", "Luke", "Angel", "Isaiah", "Brandon", "Jack", "Jordan", "Owen", "Carter", "Connor", "Justin", "Jeremiah", "Jose", "Julian", "Robert", "Aaron", "Adrian", "Wyatt", "Kevin", "Hunter", "Cameron", "Zachary", "Thomas", "Charles", "Austin", "Eli", "Chase", "Henry", "Sebastian", "Jason", "Levi", "Xavier", "Ian", "Colton", "Dominic", "Cooper", "Juan", "Josiah", "Ayden", "Luis", "Adam", "Nathaniel", "Carson", "Brody", "Tristan", "Parker", "Diego", "Blake", "Oliver", "Carlos", "Cole", "
# %%
assessors = ["Noah", "Liam", "William", "Mason", "James", "Benjamin", "Jacob", "Michael", "Emma", "Olivia", "Ava", "Sophia", "Isabella", "Mia", "Charlotte", "Abigail", "Emily", "Harper", "Amelia", "Evelyn", "Elizabeth", "Sofia", "Madison"]

# %%
assessment = pd.DataFrame({ "Case_Number" : np.random.randint(1000000,10000000,25000)})

# %%
assessment
# Out:
#        Case_Number
# 0          5051164
# 1          9034047
# 2          8415577
# 3          3724936
# 4          9556296
# ...            ...
# 24995      3729671
# 24996      1607109
# 24997      9557736
# 24998      6050659
# 24999      2347121
#
# [25000 rows x 1 columns]

# %%
assessment["First Name"] = np.random.choice(list(first), len(assessment))

# %%
assessment["Last Name"] = np.random.choice(list(last), len(assessment))

# %%
assessment["Child_Name"] = assessment["First Name"] + " " + assessment["Last Name"]

# %%
assessment.drop(columns=['First Name', 'Last Name'], inplace=True)

# %%
assessment['DOB'] = [np.random.choice(pd.date_range(datetime.datetime(2003,1,1),datetime.datetime(2018,12,31))) for i in range(25000)]

# %%
assessment["Date_of_Assessment"] = [np.random.choice(pd.date_range(datetime.datetime(2020,1,1),datetime.datetime(2020,9,9))) for i in range(25000)]

# %%
assessment["Assessor"] = np.random.choice(list(assessors), len(assessment))

# %%
assessment["DOB"] = pd.to_datetime(assessment["DOB"]).dt.strftime('%m/%d/%Y')

# %%
assessment["Date_of_Assessment"] = pd.to_datetime(assessment["Date_of_Assessment"]).dt.strftime('%m/%d/%Y')

# %%
assessment
# Out:
#        Case_Number       Child_Name         DOB Date_of_Assessment Assessor
# 0          5051164    Sergio THOMAS  09/20/2016         05/16/2020     Liam
# 1          9034047    Rebecca BAKER  12/18/2017         07/28/2020   Olivia
# 2          8415577   Peter MARTINEZ  03/03/2006         04/12/2020  William
# 3          3724936      Layla SMITH  12/31/2016         05/29/2020   Amelia
# 4          9556296     Hector YOUNG  04/01/2015         07/27/2020    Emily
# ...            ...              ...         ...                ...      ...
# 24995      3729671      Jake HARRIS  02/16/2010         07/31/2020   Amelia
# 24996      1607109  Katherine GREEN  08/23/2012         08/27/2020  Abigail
# 24997      9557736   Destiny MARTIN  04/05/2008         09/09/2020   Evelyn
# 24998      6050659   Matthew PARKER  01/02/2013         04/21/2020    Jacob
# 24999      2347121   Johnathan HALL  04/12/2003         04/03/2020   Olivia
#
# [25000 rows x 5 columns]

# %%
data = np.random.randint(0,4, size=(25000,60))

# %%
cans = pd.DataFrame(data, columns=data_col)

# %%
cans
# Out:
#        Family_Functioning  Living_Situation  Social_Functioning  Recreational  \
# 0                       3                 0                   0             0
# 1                       2                 2                   1             2
# 2                       3                 3                   1             0
# 3                       2                 3                   0             1
# 4                       3                 3                   0             0
# ...                   ...               ...                 ...           ...
# 24995                   0                 1                   2             0
# 24996                   1                 2                   3             3
# 24997                   0                 0                   3             2
# 24998                   1                 3                   0             1
# 24999                   0                 1                   2             1
#
# ...

# %%
main_df = pd.concat([assessment,cans], axis=1)

# %%
main_df
# Out:
#        Case_Number       Child_Name         DOB Date_of_Assessment Assessor  \
# 0          5051164    Sergio THOMAS  09/20/2016         05/16/2020     Liam
# 1          9034047    Rebecca BAKER  12/18/2017         07/28/2020   Olivia
# 2          8415577   Peter MARTINEZ  03/03/2006         04/12/2020  William
# 3          3724936      Layla SMITH  12/31/2016         05/29/2020   Amelia
# 4          9556296     Hector YOUNG  04/01/2015         07/27/2020    Emily
# ...            ...              ...         ...                ...      ...
# 24995      3729671      Jake HARRIS  02/16/2010         07/31/2020   Amelia
# 24996      1607109  Katherine GREEN  08/23/2012         08/27/2020  Abigail
# 24997      9557736   Destiny MARTIN  04/05/2008         09/09/2020   Evelyn
# 24998      6050659   Matthew PARKER  01/02/2013         04/21/2020    Jacob
# 24999      2347121   Johnathan HALL  04/12/2003         04/03/2020   Olivia
#
# ...

# %%
main_df.drop_duplicates(subset=['Case_Number'], inplace=True)

# %%
main_df.head(2)
# Out:
#    Case_Number     Child_Name         DOB Date_of_Assessment Assessor  \
# 0      5051164  Sergio THOMAS  09/20/2016         05/16/2020     Liam
# 1      9034047  Rebecca BAKER  12/18/2017         07/28/2020   Olivia
#
#    Family_Functioning  Living_Situation  Social_Functioning  Recreational  \
# 0                   3                 0                   0             0
# 1                   2                 2                   1             2
#
#    Developmental_Intellectual  Job Functioning  Legal  Medical_Physical  \
# 0                           0                3      0                 3
# 1                           1                3      3                 2
#
#    Sexual Development  Sleep  School_Behavior  School_Attendance  \
# 0                   0      1                0                  3
# 1                   2      3                1                  2
#
#    School_Achievement  Decision_Making  Family_Strengths  Interpersonal  \
# ...

# %% [markdown]
# ## Create Module Masks

# %%
developmental_module = main_df[main_df['Developmental_Intellectual'] > 0]
trauma_module = main_df[main_df['Adjustment_to_Trauma'] > 0]
substance_module = main_df[main_df['Substance_Use'] > 0]
violence_module = main_df[main_df['Danger_to_Others'] > 0]
sexual_module = main_df[main_df['Sexual_Aggression'] > 0]
runaway_module = main_df[main_df['Runaway'] > 0]
juvenile_module = main_df[main_df['Delinquent_Behavior'] > 0]
fire_module = main_df[main_df['Fire_Setting'] > 0]

# %%
main_df.to_csv('main_df.csv', index=False)

# %%
main_df.to_excel('main_df.xlsx', index=False)

# %%
developmental_module.head()
# Out:
#    Case_Number      Child_Name         DOB Date_of_Assessment Assessor  \
# 1      9034047   Rebecca BAKER  12/18/2017         07/28/2020   Olivia
# 2      8415577  Peter MARTINEZ  03/03/2006         04/12/2020  William
# 3      3724936     Layla SMITH  12/31/2016         05/29/2020   Amelia
# 4      9556296    Hector YOUNG  04/01/2015         07/27/2020    Emily
# 6      6606037       Zion HALL  05/08/2012         04/23/2020    Sofia
#
#    Family_Functioning  Living_Situation  Social_Functioning  Recreational  \
# 1                   2                 2                   1             2
# 2                   3                 3                   1             0
# 3                   2                 3                   0             1
# 4                   3                 3                   0             0
# 6                   2                 1                   1             2
#
#    Developmental_Intellectual  Job Functioning  Legal  Medical_Physical  \
# ...

# %%
developmental_module.shape
developmental_module['Cognitive'] = np.random.randint(0,4, size=(18726,1))
developmental_module['Communication'] = np.random.randint(0,4, size=(18726,1))
developmental_module['Develop'] = np.random.randint(0,4, size=(18726,1))
developmental_module['Self_Care'] = np.random.randint(0,4, size=(18726,1))
# Out:
# C:\Users\blang\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\blang\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\blang\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
trauma_module.shape
trauma_module['Sexual_Abuse'] = np.random.randint(0,2, size=(18719,1))
trauma_module['Physical_Abuse'] = np.random.randint(0,2, size=(18719,1))
trauma_module['Neglect'] = np.random.randint(0,2, size=(18719,1))
trauma_module['Emotional_Abuse'] = np.random.randint(0,2, size=(18719,1))
trauma_module['Medical Trauma'] = np.random.randint(0,2, size=(18719,1))
trauma_module['Natural or Manmade Disaster'] = np.random.randint(0,2, size=(18719,1))
trauma_module['Witness to Family Violence'] = np.random.randint(0,2, size=(18719,1))
trauma_module['Witness to Community_School Violence'] = np.random.randint(0,2, size=(18719,1))
trauma_module['Victim_Witness to Criminal Activity'] = np.random.randint(0,2, size=(18719,1))
trauma_module['War_Terrorism Affected'] = np.random.randint(0,2, size=(18719,1))
trauma_module['Disruptions in Caregiving_Attachment Losses'] = np.random.randint(0,2, size=(18719,1))
trauma_module['Parental Criminal Behavior'] = np.random.randint(0,2, size=(18719,1))
trauma_module['Emotional Closeness'] = np.random.randint(0,4, size=(18719,1))
trauma_module['Frequency of Abuse'] = np.random.randint(0,4, size=(18719,1))
trauma_module['Duration'] = np.random.randint(0,4, size=(18719,1))
trauma_module['Force'] = np.random.randint(0,4, size=(18719,1))
trauma_module['Reaction to Disclosure'] = np.random.randint(0,4, size=(18719,1))
trauma_module['Emotional_Physical Dysregulation'] = np.random.randint(0,4, size=(18719,1))
trauma_module['Intrusions_Re_Experiencing'] = np.random.randint(0,4, size=(18719,1))
trauma_module['Hyperarousal'] = np.random.randint(0,4, size=(18719,1))
trauma_module['Traumatic Grief'] = np.random.randint(0,4, size=(18719,1))
trauma_module['Numbing'] = np.random.randint(0,4, size=(18719,1))
trauma_module['Dissociation'] = np.random.randint(0,4, size=(18719,1))
trauma_module['Avoidance'] = np.random.randint(0,4, size=(18719,1))
# Out:
# C:\Users\blang\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\blang\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\blang\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
substance_module.shape
substance_module['Severity of Use'] = np.random.randint(0,4, size=(18789,1))
substance_module['Duration of Use'] = np.random.randint(0,4, size=(18789,1))
substance_module['Stage of Recovery'] = np.random.randint(0,4, size=(18789,1))
substance_module['Peer Influences'] = np.random.randint(0,4, size=(18789,1))
substance_module['Parental Influences'] = np.random.randint(0,4, size=(18789,1))
substance_module['Environmental Influences'] = np.random.randint(0,4, size=(18789,1))
# Out:
# C:\Users\blang\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\blang\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\blang\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
violence_module.shape
violence_module['History of Physical Abuse'] = np.random.randint(0,4, size=(18735,1))
violence_module['History of Violence'] = np.random.randint(0,4, size=(18735,1))
violence_module['Witness to Domestic Abuse'] = np.random.randint(0,4, size=(18735,1))
violence_module['Witness to Environmental Violence'] = np.random.randint(0,4, size=(18735,1))
violence_module['Bullying'] = np.random.randint(0,4, size=(18735,1))
violence_module['Frustration Management'] = np.random.randint(0,4, size=(18735,1))
violence_module['Hostility'] = np.random.randint(0,4, size=(18735,1))
violence_module['Paranoid Thinking'] = np.random.randint(0,4, size=(18735,1))
violence_module['Secondary Gains from Anger'] = np.random.randint(0,4, size=(18735,1))
violence_module['Violent Thinking'] = np.random.randint(0,4, size=(18735,1))
violence_module['Aware of Violence Potential'] = np.random.randint(0,4, size=(18735,1))
violence_module['Response to Consequences'] = np.random.randint(0,4, size=(18735,1))
violence_module['Commitment to Self-Control'] = np.random.randint(0,4, size=(18735,1))
violence_module['Treatment Involvement'] = np.random.randint(0,4, size=(18735,1))
# Out:
# C:\Users\blang\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\blang\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\blang\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
sexual_module.shape
sexual_module['Relationship'] = np.random.randint(0,4, size=(18855,1))
sexual_module['Physical Force/Threat'] = np.random.randint(0,4, size=(18855,1))
sexual_module['Planning'] = np.random.randint(0,4, size=(18855,1))
sexual_module['Age Differential'] = np.random.randint(0,4, size=(18855,1))
sexual_module['Type of Sex Act'] = np.random.randint(0,4, size=(18855,1))
sexual_module['Response to Accusation'] = np.random.randint(0,4, size=(18855,1))
sexual_module['Temporal Consistency'] = np.random.randint(0,4, size=(18855,1))
sexual_module['History of Sexual Abusive Behavior'] = np.random.randint(0,4, size=(18855,1))
sexual_module['Severity of Sexual Abuse'] = np.random.randint(0,4, size=(18855,1))
sexual_module['Prior Treatment'] = np.random.randint(0,4, size=(18855,1))
# Out:
# C:\Users\blang\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\blang\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\blang\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
runaway_module.shape
runaway_module['Frequency of Running'] = np.random.randint(0,4, size=(18636,1))
runaway_module['Consistency of Destination'] = np.random.randint(0,4, size=(18636,1))
runaway_module['Safety of Destination'] = np.random.randint(0,4, size=(18636,1))
runaway_module['Involvement in Illegal Acts'] = np.random.randint(0,4, size=(18636,1))
runaway_module['Likelihood of Return on Own'] = np.random.randint(0,4, size=(18636,1))
runaway_module['Involvement of Others'] = np.random.randint(0,4, size=(18636,1))
runaway_module['Realistic Expectations'] = np.random.randint(0,4, size=(18636,1))
runaway_module['Planning'] = np.random.randint(0,4, size=(18636,1))
# Out:
# C:\Users\blang\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\blang\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\blang\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
juvenile_module.shape
juvenile_module['History'] = np.random.randint(0,4, size=(18774,1))
juvenile_module['Seriousness'] = np.random.randint(0,4, size=(18774,1))
juvenile_module['Planning'] = np.random.randint(0,4, size=(18774,1))
juvenile_module['Community Safety'] = np.random.randint(0,4, size=(18774,1))
juvenile_module['Peer Influences'] = np.random.randint(0,4, size=(18774,1))
juvenile_module['Parental Criminal Behavior'] = np.random.randint(0,4, size=(18774,1))
juvenile_module['Environmental Influences'] = np.random.randint(0,4, size=(18774,1))
# Out:
# C:\Users\blang\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\blang\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\blang\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
fire_module.shape
fire_module['History'] = np.random.randint(0,4, size=(18665,1))
fire_module['Seriousness'] = np.random.randint(0,4, size=(18665,1))
fire_module['Planning'] = np.random.randint(0,4, size=(18665,1))
fire_module['Use of Accelerants'] = np.random.randint(0,4, size=(18665,1))
fire_module['Intention to Harm'] = np.random.randint(0,4, size=(18665,1))
fire_module['Community Safety'] = np.random.randint(0,4, size=(18665,1))
fire_module['Response to Accusation'] = np.random.randint(0,4, size=(18665,1))
# Out:
# C:\Users\blang\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\blang\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\blang\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
developmental_module.to_csv('developmenatal.csv', index=False)
trauma_module.to_csv('trauma.csv', index=False)
substance_module.to_csv('substance.csv', index=False)
violence_module.to_csv('violence.csv', index=False)
sexual_module.to_csv('sexual.csv', index=False)
runaway_module.to_csv('runaway.csv', index=False)
juvenile_module.to_csv('juvenile.csv', index=False)
fire_module.to_csv('fire.csv', index=False)

# %% [markdown]
# ## Create a final dataframe for minors that appeared in all modules

# %%
dfs = [developmental_module, trauma_module, substance_module, violence_module, sexual_module, runaway_module, juvenile_module, fire_module]

# %%
from functools import reduce

# %%
df_final = reduce(lambda left,right: pd.merge(left,right,on='Case_Number'), dfs)

# %%
df_final.head()
# Out:
#    Case_Number      Child_Name_x       DOB_x Date_of_Assessment_x Assessor_x  \
# 0      8415577    Peter MARTINEZ  03/03/2006           04/12/2020    William
# 1      6606037         Zion HALL  05/08/2012           04/23/2020      Sofia
# 2      3036529       Scott JONES  04/23/2015           05/02/2020    Michael
# 3      3354132  Charlotte PARKER  05/29/2011           09/02/2020    William
# 4      6135191      Corey WRIGHT  11/24/2017           02/15/2020        Mia
#
#    Family_Functioning_x  Living_Situation_x  Social_Functioning_x  \
# 0                     3                   3                     1
# 1                     2                   1                     1
# 2                     1                   3                     1
# 3                     2                   0                     1
# 4                     0                   0                     3
#
#    Recreational_x  Developmental_Intellectual_x  Job Functioning_x  Legal_x  \
# ...

# %%
df_final.shape
# Out:
# (2539, 593)

# %%
df_final.describe()
# Out:
#         Case_Number  Family_Functioning_x  Living_Situation_x  \
# count  2.539000e+03           2539.000000         2539.000000
# mean   5.382823e+06              1.499015            1.505711
# std    2.581842e+06              1.107455            1.121582
# min    1.012480e+06              0.000000            0.000000
# 25%    3.160200e+06              1.000000            0.000000
# 50%    5.440179e+06              2.000000            2.000000
# 75%    7.504858e+06              2.000000            3.000000
# max    9.999095e+06              3.000000            3.000000
#
#        Social_Functioning_x  Recreational_x  Developmental_Intellectual_x  \
# count           2539.000000     2539.000000                   2539.000000
# mean               1.461599        1.471445                      1.995668
# std                1.115300        1.117361                      0.832021
# min                0.000000        0.000000                      1.000000
# ...

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df_final.corr(), annot=True, cmap='magma')
